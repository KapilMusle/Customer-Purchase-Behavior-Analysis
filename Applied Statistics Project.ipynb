# %% [markdown]
# # **Customer Purchase Behavior Analysis using Descriptive Statistics**
#
# # **Name - Kapil Musle**

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load Dataset
#mount the drive to the notebook
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the dataset from an CSV file
df =pd.read_csv("/content/drive/MyDrive/Project/Mod 5 (Applied Stats)/Superstore Marketing Data.xlsx - Sheet1.csv")
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.shape
# Out:
# (2240, 22)

# %%
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Id','Dt_Customer','Complain'], axis=1)
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0           1970  Graduation       Divorced  84835.0        0         0
# 1           1961  Graduation         Single  57091.0        0         0
# 2           1958  Graduation        Married  67267.0        0         1
# 3           1967  Graduation       Together  32474.0        1         1
# 4           1989  Graduation         Single  21474.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 2235        1976         PhD       Divorced  66476.0        0         1
# 2236        1977    2n Cycle        Married  31056.0        1         0
# 2237        1976  Graduation       Divorced  46310.0        1         0
# 2238        1978  Graduation        Married  65819.0        0         0
# 2239        1969         PhD        Married  94871.0        0         2
#
#       Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# ...

# %%
df['Year_Birth'].describe()
# Out:
# count    2240.000000
# mean     1968.805804
# std        11.984069
# min      1893.000000
# 25%      1959.000000
# 50%      1970.000000
# 75%      1977.000000
# max      1996.000000
# Name: Year_Birth, dtype: float64

# %%
plt.figure(figsize=(7, 5))
sns.histplot(df['Year_Birth'], bins=30, kde=True, color='darkblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
#visualisation

# Use the "pastel" color palette for the countplot
custom_palette = sns.color_palette("pastel", len(df['Education'].value_counts()))

# Create the countplot with the "pastel" color palette
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Education', order=df['Education'].value_counts().index, palette=custom_palette)
plt.title('Education Distribution', fontsize=12)
plt.xlabel('Education Level', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-221-22637d44cce4>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Education', order=df['Education'].value_counts().index, palette=custom_palette)

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
#VISUALISATION OF MATRITAL STATUS DISTRIBUTION
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Marital_Status', order=df['Marital_Status'].value_counts().index, palette='pastel')
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-223-5990bf195be8>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Marital_Status', order=df['Marital_Status'].value_counts().index, palette='pastel')

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
#   1) There are 2240 rows and 22 columns.
#
#   2) dtypes are integer, object and float.
#
#   3) Drop columns -Id, Dt_Customer, Complain (  As they do not seems necessary for the analysis. New dataset's dimensions is 2240 rows and 19 columns.")
#
#   4) We have identified 24 null values in the Income column. (We are proceeding without imputing these missing values.Since the number are comparatively so small to effect our analysis)
#
#   5) Dropping duplicates values for maintain consistency in data and no repetation of data as well.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.
#
#   Distribution of data among Year_Birth, education and marital status.
#
#   1) Mostly year birh 1960- 1980 are the cusomers.
#
#   2) Graduation number is high.
#
#   3) Married couples are mostly engaged in shopping.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %%
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
# Define key variables
key_variables = ['Income', 'Year_Birth', 'Kidhome', 'Teenhome', 'Recency',
                 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
                 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
                 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
                 'NumWebVisitsMonth', 'Response', 'Complain']

# Calculate measures of central tendency
central_tendency = df[key_variables].agg(['mean', 'median', lambda x: x.mode().iloc[0]])

# Calculate measures of dispersion
variance = df[key_variables].var()
std_deviation = df[key_variables].std()

# Display the results
print("Measures of Central Tendency (Mean, Median, Mode):")
print(central_tendency)
print("\nVariance:")
print(variance)
print("\nStandard Deviation:")
print(std_deviation)
# Out:
# Measures of Central Tendency (Mean, Median, Mode):
#                 Income   Year_Birth   Kidhome  Teenhome    Recency  \
# mean      52247.251354  1968.805804  0.444196   0.50625  49.109375
# median    51381.500000  1970.000000  0.000000   0.00000  49.000000
# <lambda>   7500.000000  1976.000000  0.000000   0.00000  56.000000
#
#             MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# mean      303.935714  26.302232           166.95        37.525446
# median    173.500000   8.000000            67.00        12.000000
# <lambda>    2.000000   0.000000             7.00         0.000000
#
#           MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# mean             27.062946     44.021875              2.325         4.084821
# median            8.000000     24.000000              2.000         4.000000
# <lambda>          0.000000      1.000000              1.000         2.000000
#
# ...

# %% [markdown]
# Below code will exclude non-numeric columns when calculating descriptive statistics, to prevent 'Graduation' value (or any other non-numeric values) from causing errors.

# %%
import pandas as pd

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Calculate descriptive statistics
descriptive_stats = numeric_columns.describe()

# Calculate mode separately for each variable
mode = numeric_columns.mode().iloc[0]

# Calculate variance separately for each variable
variance = numeric_columns.var()

# Calculate standard deviation separately for each variable
std_deviation = numeric_columns.std()

# Display the descriptive statistics
print("Descriptive Statistics:")
print(descriptive_stats)

# Display the mode for each variable
print("\nMode:")
print(mode)

# Display the variance for each variable
print("\nVariance:")
print(variance)

# Display the standard deviation for each variable
print("\nStandard Deviation:")
print(std_deviation)
# Out:
# Descriptive Statistics:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# **Binomial Distribution for 'Complain' Variable:**
#
#
# *  Complain: Complain variable represents whether a customer have complained in the last 2 years (1 if complained, 0 otherwise).

# %%
from scipy.stats import binom

# Probability of a customer complaining (complain=1)
p_complain = df['Complain'].mean()

# Expected number of customers complaining
e_complainers = len(df) * p_complain

print(f"Probability of a customer complaining customer : {p_complain:.4f}")
print(f"Expected number of complainers: {e_complainers:.2f}")
# Out:
# Probability of a customer complaining customer : 0.0094
# Expected number of complainers: 21.00

# %% [markdown]
# **Poisson Distribution for 'NumDealsPurchases' Variable:**
#
# *   This variable represents the number of purchases made with a discount, which could potentially follow a Poisson distribution if the number of events (discount purchases) is rare and independent.
# *   We fit a Poisson distribution to the 'NumDealsPurchases' data and calculate the probability of a specific number of discount purchases (e.g., 2).

# %%
from scipy.stats import poisson

# Fit a Poisson distribution to the NumDealsPurchases data
mu_purchases = df['NumDealsPurchases'].mean()

# Probability of a specific number of discount purchases (e.g., 2)
probability_2_discount_purchases = poisson.pmf(2, mu_purchases)

print(f"Mean of discount purchases: {mu_purchases:.2f}")
print(f"Probability of 2 discount purchases: {probability_2_discount_purchases:.4f}")
# Out:
# Mean of discount purchases: 2.33
# Probability of 2 discount purchases: 0.2643

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Exclude non-numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='seismic', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
# Boxplot of spending habits based on education level
plt.figure(figsize=(8, 6))
sns.boxplot(x='Education', y='MntWines', data=df, palette='Set2')
plt.title('Wine Spending based on Education Level')
plt.xlabel('Education Level')
plt.ylabel('Amount Spent on Wines')
plt.show()
# Out:
# <ipython-input-230-674cf4a71ee6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education', y='MntWines', data=df, palette='Set2')

# %% [markdown]
# Education plays a crucial role in shaping purchasing interests, as evident from the second chart. Individuals with a PhD tend to allocate a larger portion of their expenditure towards wine purchases compared with other educational backgrounds.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# **This code/visualizations includes:**
#
# *   Relationship between age and spending on wines, with education level as a hue.
# *  Segmentation of customers based on age and income, with cluster labels represented by different colors and styles.
# *   Recommendations based on the insights derived from the visualizations.

# %% [markdown]
# **Visualize Spending Across Product Categories:**

# %%
import matplotlib.pyplot as plt

# Plot total spending across product categories
plt.figure(figsize=(10, 6))
df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum().plot(kind='bar', color='blue')
plt.title('Total Spending Across Product Categories')
plt.xlabel('Product Categories')
plt.ylabel('Total Spending')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Plot relationship between age and spending on wines
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year_Birth', y='MntWines', data=df, hue='Education', palette='Set2')
plt.title('Relationship between Age and Spending on Wines by Education Level')
plt.xlabel('Year of Birth')
plt.ylabel('Spending on Wines')
plt.legend(title='Education')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans


# Preprocess the data
df = df.dropna(subset=['Year_Birth', 'Income'])

# Ensure the columns are numeric
df.loc[:, 'Year_Birth'] = pd.to_numeric(df['Year_Birth'], errors='coerce')
df.loc[:, 'Income'] = pd.to_numeric(df['Income'], errors='coerce')

# Drop any rows with NaN values in 'Year_Birth' or 'Income' columns
df = df.dropna(subset=['Year_Birth', 'Income'])

# Normalize the data for clustering
scaler = StandardScaler()
df[['Year_Birth', 'Income']] = scaler.fit_transform(df[['Year_Birth', 'Income']])

# Define the number of clusters
num_clusters = 3

# Apply K-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(df[['Year_Birth', 'Income']])

# Segment customers based on age and income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year_Birth', y='Income', data=df, hue='Cluster', palette='Set1', style='Cluster', s=100)
plt.title('Customer Segmentation based on Year of Birth and Income')
plt.xlabel('Year of Birth')
plt.ylabel('Income')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# Make recommendations
print("Recommendations:")
print("- Target marketing campaigns towards younger customers with higher income, as they represent a lucrative segment for wine purchases.")
print("- Tailor promotions and discounts based on customer segmentation to incentivize spending and increase customer engagement.")
print("- Collect feedback from customers with different education levels to understand their preferences and tailor product offerings accordingly.")
# Out:
# Recommendations:
# - Target marketing campaigns towards younger customers with higher income, as they represent a lucrative segment for wine purchases.
# - Tailor promotions and discounts based on customer segmentation to incentivize spending and increase customer engagement.
# - Collect feedback from customers with different education levels to understand their preferences and tailor product offerings accordingly.

# %% [markdown]
# # **Insights and Recommendations**
#
# #Based on the visualizations, you can derive the following insights and recommendations:
#
# #Age and Wine Spending:
#
# *   If you notice that younger customers tend to spend more on wines and have higher education levels, target marketing campaigns towards this demographic. *   Tailor advertisements to highlight premium wine selections and exclusive offers that appeal to their tastes.
#
# #Customer Segmentation:
#
# Analyze the clusters to understand the distinct segments. For example, if you have three clusters, you might find:
# Cluster 0: Younger customers with higher income. Focus on premium products and exclusive events.
# Cluster 1: Middle-aged customers with moderate income. Offer a mix of mid-range and premium products, with occasional discounts.
# Cluster 2: Older customers with lower income. Provide value-for-money products and loyalty programs to retain them.
#
# #Education Level:
#
# *   Use the insights from the education level to tailor communication. For highly educated customers, provide detailed product information and reviews. For others, focus on visual appeal and emotional marketing.
#
# #General Recommendations:
#
# *   Target Marketing Campaigns: Tailor marketing campaigns based on the identified segments. Younger, higher-income customers might respond well to digital marketing and social media campaigns.
# *   Personalized Offers: Use the cluster information to personalize offers and discounts. Younger, high-income customers could be offered premium memberships or exclusive deals.
# *   Feedback Collection: Collect feedback from different segments to understand their preferences and adjust product offerings accordingly. This can help in refining the marketing strategies and improving customer satisfaction.
#
# By implementing these recommendations, you can optimize marketing efforts, increase customer engagement, and improve offer acceptance rates.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
